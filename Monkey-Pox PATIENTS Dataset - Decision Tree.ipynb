# %% [markdown]
# ### Monkey-Pox PATIENTS Dataset

# %% [markdown]
# ### Context
# - An ongoing outbreak of monkeypox, a viral disease, was confirmed in May 2022. The initial cluster of cases was found in the United Kingdom, where the first case was detected in London on 6 May 2022 in a patient with a recent travel history from Nigeria.

# %% [markdown]
# ### Content
# - This is a SYNTHETIC dataset generated based on a study published by thebmj: Clinical features and novel presentations of human monkeypox in a central London centre during the 2022 outbreak: descriptive case series.
#
# - Dataset consists of a CSV which have a record of 25,000 Patients with their corresponding features and a target variable indicating if the patient has monkeypox or not.
#
# ### Features:
# - Patient_ID, Systemic Illness, Rectal Pain, Sore Throat, Penile Oedema, Oral Lesions, Solitary Lesion, Swollen Tonsils, HIV Infection, and Sexually Transmitted Infection
#
# ### Target Variable: MonkeyPox
# - The dataset currently contains boolean and categorical features and in future, we might add more data and features to help you identify the patients of Monkey-Pox.

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Data Lookup & Cleaning

# %% [markdown]
# #### Reading the Dataset and assigning that to the variable df

# %%
df=pd.read_csv("Monkey-Pox PATIENTS Dataset.csv")
df
# Out:
#       Patient_ID     Systemic Illness  Rectal Pain  Sore Throat  \
# 0             P0                 None        False         True
# 1             P1                Fever         True        False
# 2             P2                Fever        False         True
# 3             P3                 None         True        False
# 4             P4  Swollen Lymph Nodes         True         True
# ...          ...                  ...          ...          ...
# 24995     P24995                 None         True         True
# 24996     P24996                Fever        False         True
# 24997     P24997                 None         True         True
# 24998     P24998  Swollen Lymph Nodes        False         True
# 24999     P24999  Swollen Lymph Nodes        False        False
#
#        Penile Oedema  Oral Lesions  Solitary Lesion  Swollen Tonsils  \
# 0               True          True            False             True
# ...

# %%
df.head()
# Out:
#   Patient_ID     Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  \
# 0         P0                 None        False         True           True
# 1         P1                Fever         True        False           True
# 2         P2                Fever        False         True           True
# 3         P3                 None         True        False          False
# 4         P4  Swollen Lymph Nodes         True         True           True
#
#    Oral Lesions  Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0          True            False             True          False
# 1          True            False            False           True
# 2         False            False            False           True
# 3         False             True             True           True
# 4         False            False             True           True
#
#    Sexually Transmitted Infection MonkeyPox
# 0                           False  Negative
# ...

# %%
df.tail()
# Out:
#       Patient_ID     Systemic Illness  Rectal Pain  Sore Throat  \
# 24995     P24995                 None         True         True
# 24996     P24996                Fever        False         True
# 24997     P24997                 None         True         True
# 24998     P24998  Swollen Lymph Nodes        False         True
# 24999     P24999  Swollen Lymph Nodes        False        False
#
#        Penile Oedema  Oral Lesions  Solitary Lesion  Swollen Tonsils  \
# 24995          False          True             True            False
# 24996           True         False             True             True
# 24997          False         False             True             True
# 24998          False          True             True             True
# 24999           True         False            False             True
#
#        HIV Infection  Sexually Transmitted Infection MonkeyPox
# 24995          False                            True  Positive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Patient_ID                      25000 non-null  object
#  1   Systemic Illness                25000 non-null  object
#  2   Rectal Pain                     25000 non-null  bool
#  3   Sore Throat                     25000 non-null  bool
#  4   Penile Oedema                   25000 non-null  bool
#  5   Oral Lesions                    25000 non-null  bool
#  6   Solitary Lesion                 25000 non-null  bool
#  7   Swollen Tonsils                 25000 non-null  bool
#  8   HIV Infection                   25000 non-null  bool
#  9   Sexually Transmitted Infection  25000 non-null  bool
#  10  MonkeyPox                       25000 non-null  object
# dtypes: bool(8), object(3)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#        Patient_ID Systemic Illness Rectal Pain Sore Throat Penile Oedema  \
# count       25000            25000       25000       25000         25000
# unique      25000                4           2           2             2
# top            P0            Fever       False        True          True
# freq            1             6382       12655       12554         12612
#
#        Oral Lesions Solitary Lesion Swollen Tonsils HIV Infection  \
# count         25000           25000           25000         25000
# unique            2               2               2             2
# top           False            True            True          True
# freq          12514           12527           12533         12584
#
#        Sexually Transmitted Infection MonkeyPox
# count                           25000     25000
# unique                              2         2
# top                             False  Positive
# freq                            12554     15909

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Patient_ID                        0
# Systemic Illness                  0
# Rectal Pain                       0
# Sore Throat                       0
# Penile Oedema                     0
# Oral Lesions                      0
# Solitary Lesion                   0
# Swollen Tonsils                   0
# HIV Infection                     0
# Sexually Transmitted Infection    0
# MonkeyPox                         0
# dtype: int64

# %%
df.corr()
# Out:
#                                 Rectal Pain  Sore Throat  Penile Oedema  \
# Rectal Pain                        1.000000     0.006214       0.005312
# Sore Throat                        0.006214     1.000000       0.009082
# Penile Oedema                      0.005312     0.009082       1.000000
# Oral Lesions                       0.007747    -0.000795       0.003850
# Solitary Lesion                    0.001147    -0.003609       0.002781
# Swollen Tonsils                    0.002113    -0.002011       0.000536
# HIV Infection                      0.005764     0.000771       0.003620
# Sexually Transmitted Infection     0.000666    -0.001901      -0.005722
#
#                                 Oral Lesions  Solitary Lesion  \
# Rectal Pain                         0.007747         0.001147
# Sore Throat                        -0.000795        -0.003609
# Penile Oedema                       0.003850         0.002781
# Oral Lesions                        1.000000        -0.005198
# ...

# %%
sns.heatmap(df.corr())
plt.show()

# %%
df.drop(['Patient_ID'],axis=1,inplace=True)
df
# Out:
#           Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  \
# 0                     None        False         True           True
# 1                    Fever         True        False           True
# 2                    Fever        False         True           True
# 3                     None         True        False          False
# 4      Swollen Lymph Nodes         True         True           True
# ...                    ...          ...          ...            ...
# 24995                 None         True         True          False
# 24996                Fever        False         True           True
# 24997                 None         True         True          False
# 24998  Swollen Lymph Nodes        False         True          False
# 24999  Swollen Lymph Nodes        False        False           True
#
#        Oral Lesions  Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0              True            False             True          False
# ...

# %% [markdown]
# ### Analysis of Data

# %%
df.groupby('MonkeyPox').size().plot(kind='pie',  textprops={'fontsize': 20},autopct='%1.0f%%')
plt.title('Percentage of the People affected by MonkeyPox')
plt.show()

# %% [markdown]
# #### Observation
# - 64% People were affected by MonkeyPox
# - 36% People were not affected by MonkeyPox

# %%
plt.figure(figsize=(8,6))
sns.countplot('Systemic Illness', data=df, hue = 'MonkeyPox')

plt.title("Systemic Illness Vs MonkeyPox")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# - If the person is affected by fever, Swollen Lymph Nodes then the chances of affected by money box is high

# %%
plt.figure(figsize=(8,6))
sns.countplot('HIV Infection', data=df, hue = 'MonkeyPox')

plt.title("HIV Infection Vs MonkeyPox")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# - If the person is having HIV, then the chances of affected by money box is high

# %%
plt.figure(figsize=(8,6))
sns.countplot('Rectal Pain', data=df, hue = 'MonkeyPox')

plt.title("Rectal Pain Vs MonkeyPox")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# - If the person is having Rectal Pain, then the chances of affected by money box is high

# %%
plt.figure(figsize=(8,6))
sns.countplot('Sore Throat', data=df, hue = 'MonkeyPox')

plt.title("Sore Throat Vs MonkeyPox")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# - If the person is having Sore Throat, then the chances of affected by money box is high

# %%
plt.figure(figsize=(8,6))
sns.countplot('Swollen Tonsils', data=df, hue = 'MonkeyPox')

plt.title("Swollen Tonsils Vs MonkeyPox")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Observation
# - If the person is having Swollen Tonsils, then the chances of affected by money box is not that much high

# %%
d=df.copy()
d
# Out:
#           Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  \
# 0                     None        False         True           True
# 1                    Fever         True        False           True
# 2                    Fever        False         True           True
# 3                     None         True        False          False
# 4      Swollen Lymph Nodes         True         True           True
# ...                    ...          ...          ...            ...
# 24995                 None         True         True          False
# 24996                Fever        False         True           True
# 24997                 None         True         True          False
# 24998  Swollen Lymph Nodes        False         True          False
# 24999  Swollen Lymph Nodes        False        False           True
#
#        Oral Lesions  Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0              True            False             True          False
# ...

# %%
for x in d.columns:
    if d[x].dtype == 'bool':
        d[x] = d[x].replace({"True":1,"False":0}).astype(int)
    else:
        continue

# %%
d['Systemic Illness'].value_counts()
# Out:
# Fever                    6382
# Swollen Lymph Nodes      6252
# None                     6216
# Muscle Aches and Pain    6150
# Name: Systemic Illness, dtype: int64

# %%
d['Systemic Illness']=d['Systemic Illness'].replace({'Fever':1,'Swollen Lymph Nodes':2,'None':0,'Muscle Aches and Pain':3})

# %%
d
# Out:
#        Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  \
# 0                     0            0            1              1
# 1                     1            1            0              1
# 2                     1            0            1              1
# 3                     0            1            0              0
# 4                     2            1            1              1
# ...                 ...          ...          ...            ...
# 24995                 0            1            1              0
# 24996                 1            0            1              1
# 24997                 0            1            1              0
# 24998                 2            0            1              0
# 24999                 2            0            0              1
#
#        Oral Lesions  Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0                 1                0                1              0
# ...

# %% [markdown]
# ### Creation of a Model

# %% [markdown]
# #### Take the X and y value

# %%
x=d.drop(["MonkeyPox"],axis=1)
x
# Out:
#        Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  \
# 0                     0            0            1              1
# 1                     1            1            0              1
# 2                     1            0            1              1
# 3                     0            1            0              0
# 4                     2            1            1              1
# ...                 ...          ...          ...            ...
# 24995                 0            1            1              0
# 24996                 1            0            1              1
# 24997                 0            1            1              0
# 24998                 2            0            1              0
# 24999                 2            0            0              1
#
#        Oral Lesions  Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0                 1                0                1              0
# ...

# %%
y=df["MonkeyPox"]
y
# Out:
# 0        Negative
# 1        Positive
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 24995    Positive
# 24996    Positive
# 24997    Positive
# 24998    Negative
# 24999    Positive
# Name: MonkeyPox, Length: 25000, dtype: object

# %%
y.value_counts()
# Out:
# Positive    15909
# Negative     9091
# Name: MonkeyPox, dtype: int64

# %% [markdown]
# #### Split the Training Dataset and Test Dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
model=DecisionTreeClassifier()

# %% [markdown]
# #### Fitting the training data to the model

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Prediction

# %%
y_predict=model.predict(X_test)
y_predict
# Out:
# array(['Positive', 'Positive', 'Positive', ..., 'Positive', 'Negative',
#        'Positive'], dtype=object)

# %% [markdown]
# ### Accuracy

# %%
accuracy_score(y_test,y_predict)*100
# Out:
# 67.44

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
performance=confusion_matrix(y_test,y_predict)

# %%
performance
# Out:
# array([[ 692, 1156],
#        [ 472, 2680]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(model,X_test,y_test)
plt.show()

# %% [markdown]
# ### Descision Tree Structure

# %%
from sklearn import tree

# %%
d
# Out:
#        Systemic Illness  Rectal Pain  Sore Throat  Penile Oedema  \
# 0                     0            0            1              1
# 1                     1            1            0              1
# 2                     1            0            1              1
# 3                     0            1            0              0
# 4                     2            1            1              1
# ...                 ...          ...          ...            ...
# 24995                 0            1            1              0
# 24996                 1            0            1              1
# 24997                 0            1            1              0
# 24998                 2            0            1              0
# 24999                 2            0            0              1
#
#        Oral Lesions  Solitary Lesion  Swollen Tonsils  HIV Infection  \
# 0                 1                0                1              0
# ...

# %%
feature_names=['Systemic Illness','Rectal Pain','Sore Throat','Penile Oedema','Oral Lesions','Solitary Lesion','Swollen Tonsils','HIV Infection','Sexually Transmitted Infection']
class_names=['Positive','Negative']
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(6,6),dpi=300,facecolor='r')
tree.plot_tree(model,feature_names=feature_names,class_names=class_names,filled=True)
fig.savefig('Monkey-Pox PATIENTS Data.png')

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array(['Positive', 'Negative', 'Positive', ..., 'Negative', 'Negative',
#        'Positive'], dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)*100
# Out:
# 66.8

# %% [markdown]
# ### Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression
model_Reg=LogisticRegression()
model_Reg.fit(x_train,y_train)
model_Reg.score(x_test,y_test)*100
# Out:
# 66.84

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn=KNeighborsClassifier()
model_knn.fit(x_train,y_train)
model_knn.score(x_test,y_test)*100
# Out:
# 64.64

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
model_sv=SVC()
model_sv.fit(x_train,y_train)
model_sv.score(x_test,y_test)*100
# Out:
# 68.62

# %% [markdown]
# ### K-Fold

# %%
def get_score(model,x_train,x_test,y_train,y_test):
    model.fit(x_train,y_train)
    return model.score(x_test,y_test)

# %%
from sklearn.model_selection import KFold
Fold=KFold(n_splits=4)

# %%
from sklearn.model_selection import cross_val_score

# %%
rf=cross_val_score(RandomForestClassifier(),x,y,cv=4)

# %%
sv=cross_val_score(SVC(),x,y,cv=4)

# %%
lg=cross_val_score(LogisticRegression(),x,y,cv=4)

# %%
knn=cross_val_score(KNeighborsClassifier(),x,y,cv=4)

# %%
print('Random Forest - ',rf)
print('Random Forest - ',np.average(rf)*100)

# %%
print('SVM - ',sv)
print('SVM - ',np.average(sv)*100)

# %%
print('Logistics Regression - ',lg)
print('Logistics Regression - ',np.average(lg)*100)

# %%
print('KNN - ',knn)
print('KNN - ',np.average(knn)*100)

# %%
score1 = cross_val_score(SVC(),x,y)
score1
np.average(score1)*100
